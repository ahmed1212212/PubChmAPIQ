# %%
from PubchemAPI import *

# %% [markdown]
# # Domain: Compound

# %%
import sys
import urllib.parse
import requests 
import time
import json
import random 
from PubchemAPI import *
# --- (The helper functions and _base_request definitions must be run first) ---

# NOTE: The full code block defining DOMAINS, PROPERTIES, make_func, 
# and the generation loops must precede this extraction code.
# Since I have the full code from your previous prompt, I will assume it ran.

# Assuming the previous code block defining Sections 0-3 has been executed...

# ==============================================================================
# 4. FUNCTION NAME EXTRACTION
# ==============================================================================

def extract_all_function_names():
    """Extracts all function names created by the dynamic generator."""
    # current_module holds all dynamically created functions
    module_dict = sys.modules[__name__].__dict__
    
    function_names = []
    
    # Iterate through all names defined in the current module
    for name in sorted(module_dict.keys()):
        # Check if the name starts with the domain prefix
        if name.startswith('compound_') or name.startswith('standardize_') or name.startswith('get_sources_'):
            # Check if the object itself is a callable function (excluding helper functions)
            if callable(module_dict[name]) and name not in ['check_pugrest_status', '_execute_request', '_base_request', 'make_func', 'run_test_case']:
                function_names.append(name)
    return function_names

# --- EXECUTION ---
generated_names = extract_all_function_names()

print("==================================================================")
print(f"| TOTAL GENERATED FUNCTIONS: {len(generated_names)}")
print("==================================================================")
print("--- COMPOUND DOMAIN FUNCTIONS ---")

# Print functions in a clean, categorized list
for name in generated_names:
    if name.startswith('compound_'):
        print(name)

print("\n--- OTHER DOMAIN FUNCTIONS (Example) ---")

# Print example functions from other domains if they exist in the full DOMAINS map
for name in generated_names:
    if name.startswith('standardize_') or name.startswith('get_sources_'):
        print(name)

# %%
import sys
import urllib.parse
import requests 
import time
import json
import random 

# --- (The helper functions and _base_request definitions must be run first) ---

# NOTE: The full code block defining DOMAINS, PROPERTIES, make_func, 
# and the generation loops must precede this extraction code.
# Since I have the full code from your previous prompt, I will assume it ran.

# Assuming the previous code block defining Sections 0-3 has been executed...

# ==============================================================================
# 4. FUNCTION NAME EXTRACTION
# ==============================================================================

def extract_all_function_names():
    """Extracts all function names created by the dynamic generator."""
    # current_module holds all dynamically created functions
    module_dict = sys.modules[__name__].__dict__
    
    function_names = []
    
    # Iterate through all names defined in the current module
    for name in sorted(module_dict.keys()):
        # Check if the name starts with the domain prefix
        if name.startswith('compound_') or name.startswith('standardize_') or name.startswith('get_sources_'):
            # Check if the object itself is a callable function (excluding helper functions)
            if callable(module_dict[name]) and name not in ['check_pugrest_status', '_execute_request', '_base_request', 'make_func', 'run_test_case']:
                function_names.append(name)
    return function_names

# --- EXECUTION ---
generated_names = extract_all_function_names()

print("==================================================================")
print(f"| TOTAL GENERATED FUNCTIONS: {len(generated_names)}")
print("==================================================================")
print("--- COMPOUND DOMAIN FUNCTIONS ---")

# Print functions in a clean, categorized list
for name in generated_names:
    if name.startswith('compound_'):
        print(name)

print("\n--- OTHER DOMAIN FUNCTIONS (Example) ---")

# Print example functions from other domains if they exist in the full DOMAINS map
for name in generated_names:
    if name.startswith('standardize_') or name.startswith('get_sources_'):
        print(name)

# %%
import requests
import requests

# 1. Generate the URL for ALL properties
urls = compound_cid_get_all_properties(2244)

# 2. Fetch the data (CSV is the default format for this operation)
# This returns a tabular view of every available property
response_lines = get_list_text_from_url(urls)

print(f"Retrieved {len(response_lines)} lines of property data.")
print("Header:", response_lines) 
# Output will include: "CID,MolecularFormula,MolecularWeight,SMILES,..."
# 1. Define the specific properties you want
my_props = ['MolecularWeight', 'XLogP', 'TPSA']

# 2. Generate the URL
# The factory dynamically builds: .../property/MolecularWeight,XLogP,TPSA/CSV
urls = compound_cid_get_properties(2244, properties=my_props)

# 3. Fetch the data
data = get_list_text_from_url(urls)

print(data)
# Output:
# ['"CID","MolecularWeight","XLogP","TPSA"', 
#  '2244,180.16,1.2,63.6']

# %%
# --- Test Parameters (Batch Focus) ---
CID_ASPIRIN = ['2244']
CID_CAFFEINE = ['2519']
# Combined list for batchable functions (CID 2244, CID 2519, CID 65028)
CID_MIXED_BATCH = ['2244', '2519', '65028'] 

SMILES_ASPIRIN_CAFFEINE = ['CC(=O)Oc1ccccc1C(=O)O', 'CN1C=NC2=C1C(=O)N(C)C(=O)N2C']
FORMULA_CAFFEINE = ['C8H10N4O2']
NAME_ASPIRIN = ['Aspirin']

print("\n==================================================================")
print("| CHEM/BIOINFORMATICS DIVERSITY TEST SUITE (BATCH POWER DEMO) |")
print("==================================================================")

# --- SECTION 1: CORE CHEMINFORMATICS PROPERTIES (CID Namespace) ---
# Goal: Retrieve common molecular descriptors using BATCHED CIDs (Functions 1-10)
print("\n--- 1. MOLECULAR DESCRIPTORS (BATCHED) ---")

# 1. Exact Mass (Batchable)
# Expects one result line per input CID
print("1. Exact Mass (BATCH):", compound_cid_get_ExactMass(CID_MIXED_BATCH))
# 2. Molecular Formula (Batchable)
print("2. Formula (BATCH):", compound_cid_get_MolecularFormula(CID_MIXED_BATCH))
# 3. Heavy Atom Count (Batchable)
print("3. Heavy Atom Count (BATCH):", compound_cid_get_HeavyAtomCount(CID_MIXED_BATCH))
# 4. TPSA (Batchable)
print("4. TPSA (BATCH):", compound_cid_get_TPSA(CID_MIXED_BATCH))
# 5. XLogP (Batchable)
print("5. XLogP (BATCH):", compound_cid_get_XLogP(CID_MIXED_BATCH))
# 6. Rotatable Bond Count (Batchable)
print("6. Rotatable Bonds (BATCH):", compound_cid_get_RotatableBondCount(CID_MIXED_BATCH))
# 7. Monoisotopic Mass (Batchable)
print("7. Monoisotopic Mass (BATCH):", compound_cid_get_MonoisotopicMass(CID_MIXED_BATCH))
# 8. SMILES String (Batchable)
print("8. Canonical SMILES (BATCH):", compound_cid_get_SMILES(CID_MIXED_BATCH))
# 9. InChIKey (Batchable)
print("9. InChIKey (BATCH):", compound_cid_get_InChIKey(CID_MIXED_BATCH))
# 10. Fingerprint 2D (Batchable)
print("10. Fingerprint 2D (BATCH):", compound_cid_get_Fingerprint2D(CID_MIXED_BATCH))


# --- SECTION 2: BIOINFORMATICS & ASSAY LOOKUPS (CID & XREF) ---
# Goal: Connect compound to biological context using BATCHED CIDs. (Functions 11-17)
print("\n--- 2. BIOLOGICAL CONTEXT & XREFS (BATCHED) ---")

# 11. GeneID Cross-Reference (Batchable)
print("11. XREF GeneID (BATCH):", compound_cid_get_xrefs_RN(CID_MIXED_BATCH))
# 12. PubMedID Cross-Reference (Batchable)
print("12. XREF PubMedID (BATCH):", compound_cid_get_xrefs_PubMedID(CID_MIXED_BATCH))
# 13. All Associated BioAssay IDs (Batchable)
print("13. All AIDs (BATCH):", compound_cid_get_aids(CID_MIXED_BATCH))
# 14. Active BioAssay IDs (Batchable)
print("14. AIDs Active (BATCH):", compound_cid_get_aids_active(CID_MIXED_BATCH))
# 15. Assay Summary (Batchable, XML output)
print("15. Assay Summary (BATCH, XML):", compound_cid_get_assaysummary(CID_MIXED_BATCH))
# 16. Classification (Batchable)
print("16. Classification (BATCH, XML):", compound_cid_get_classification(CID_MIXED_BATCH))
# 17. PatentID Cross-Reference (Batchable)
print("17. XREF PatentID (BATCH):", compound_cid_get_xrefs_PatentID(CID_MIXED_BATCH))


# --- SECTION 3: STRUCTURAL & VARIANT SEARCHES (Single Input Focus) ---
# NOTE: Structural searches must remain single input to work as intended. (Functions 18-24)
print("\n--- 3. STRUCTURAL & VARIANT SEARCHES (SINGLE) ---")

# 18. Formula Lookups (CIDs by Formula)
print("18. CIDs by Formula (Caffeine Formula):", compound_formula_get_cids(FORMULA_CAFFEINE))

# 19. Fast Identity Search by CID 
print("19. FastIdentity (Aspirin CID):", compound_fastidentity_cid_get_cids(CID_ASPIRIN))

# 20. Fast Identity Search by SMILES 
# Tests single-ID structure using encoded SMILES string
print("20. FastIdentity (Aspirin/Caffeine SMILES):", compound_fastidentity_smiles_get_cids(SMILES_ASPIRIN_CAFFEINE[0])) 

# 21. Tautomer Search (Single ID)
print("21. CIDs Same Tautomer (Aspirin):", compound_cid_get_cids_same_tautomer(CID_ASPIRIN))

# 22. Stereoisomer Search (Single ID)
print("22. CIDs Same Stereo (Aspirin):", compound_cid_get_cids_same_stereo(CID_ASPIRIN))

# 23. Parent Compound Lookup (Single ID)
print("23. CIDs Parent (Aspirin):", compound_cid_get_cids_parent(CID_ASPIRIN))

# 24. Conformer Data Retrieval (Single ID)
print("24. Conformers (XML Output):", compound_cid_get_conformers(CID_ASPIRIN))


# --- SECTION 4: GENERAL I/O AND METADATA (Batching & Output Types) ---
# Goal: Test diverse outputs, including image and general metadata. (Functions 25-30)
print("\n--- 4. I/O, METADATA & NON-CID LOOKUPS ---")

# 25. Retrieval of IUPAC Name (Non-CID input)
print("25. IUPAC Name (Aspirin Name):", compound_name_get_IUPACName(NAME_ASPIRIN))
# 26. Retrieval of Dates (Batchable)
print("26. Dates (BATCH, JSON Output):", compound_cid_get_dates(CID_MIXED_BATCH))
# 27. Retrieval of Description (Batchable)
print("27. Description (BATCH, XML Output):", compound_cid_get_description(CID_MIXED_BATCH))
# 28. Standard SIDs (Substance IDs) Retrieval (Batchable)
print("28. SIDs (BATCH):", compound_cid_get_sids(CID_MIXED_BATCH))
# 29. Retrieve 2D Image (Single ID)
print("29. PNG 2D Image URL (Aspirin):", compound_cid_get_png_2d(CID_ASPIRIN, image_size='large'))
# 30. Retrieve 3D Image (Single ID)
print("30. PNG 3D Image URL (Aspirin):", compound_cid_get_png_3d(CID_ASPIRIN, image_size='large'))

# %% [markdown]
# # Domain: Substance

# %%
import sys
import urllib.parse
import requests 
import time
import json
import random 

# --- (The helper functions and _base_request definitions must be run first) ---

# NOTE: The full code block defining DOMAINS, PROPERTIES, make_func, 
# and the generation loops must precede this extraction code.
# Since I have the full code from your previous prompt, I will assume it ran.

# Assuming the previous code block defining Sections 0-3 has been executed...

# ==============================================================================
# 4. FUNCTION NAME EXTRACTION
# ==============================================================================

def extract_all_function_names():
    """Extracts all function names created by the dynamic generator."""
    # current_module holds all dynamically created functions
    module_dict = sys.modules[__name__].__dict__
    
    function_names = []
    
    # Iterate through all names defined in the current module
    for name in sorted(module_dict.keys()):
        # Check if the name starts with the domain prefix
        if name.startswith('substance_') or name.startswith('standardize_') or name.startswith('get_sources_'):
            # Check if the object itself is a callable function (excluding helper functions)
            if callable(module_dict[name]) and name not in ['check_pugrest_status', '_execute_request', '_base_request', 'make_func', 'run_test_case']:
                function_names.append(name)
    return function_names

# --- EXECUTION ---
generated_names = extract_all_function_names()

print("==================================================================")
print(f"| TOTAL GENERATED FUNCTIONS: {len(generated_names)}")
print("==================================================================")
print("--- COMPOUND DOMAIN FUNCTIONS ---")

# Print functions in a clean, categorized list
for name in generated_names:
    if name.startswith('substance_'):
        print(name)

print("\n--- OTHER DOMAIN FUNCTIONS (Example) ---")

# Print example functions from other domains if they exist in the full DOMAINS map
for name in generated_names:
    if name.startswith('standardize_') or name.startswith('get_sources_'):
        print(name)

# %%
# --- Test Parameters for SUBSTANCE Domain ---
SID_SINGLE = ['173169824'] 
SID_BATCH = ['173169824', '135311827', '242008']
NAME_SINGLE = ['Benzene']
SOURCE_ID_SINGLE = ['CID241']
SOURCE_ALL_SINGLE = ['ChEBI']
LISTKEY_DUMMY = ['C0B0A11B-5555-5555-5555-A9B0B11B']

print("\n==================================================================")
print("| SUBSTANCE DOMAIN TEST SUITE (30 FUNCTIONS - FINAL FIX) |")
print("==================================================================")

# --- SECTION 1: SID LOOKUPS (Primary Identifier, Retrieval, and Batching) ---
# Namespace: sid
print("\n--- 1. SID LOOKUPS ---")

# 1. Substance Record Retrieval (Single SID - XML)
print("1. SID Record (Single):", substance_sid_get_record(SID_SINGLE))
# 2. Substance Synonyms Retrieval (Batch SID - TXT)
print("2. SID Synonyms (Batch):", substance_sid_get_synonyms(SID_BATCH))
# 3. Get Associated CIDs (Cross-Domain Lookup, Batch)
print("3. SID to CIDs (Batch):", substance_sid_get_cids(SID_BATCH))
# 4. Get Standardized CIDs (Batch)
print("4. SID to Standardized CIDs (Batch):", substance_sid_get_cids_standardized(SID_BATCH))
# 5. Get Original SIDs (Self-lookup validation)
print("5. SID Get SIDs Original (Batch):", substance_sid_get_sids_original(SID_BATCH))
# 6. Get Associated AIDs (Bioactivity)
print("6. SID Get AIDs (Batch):", substance_sid_get_aids(SID_BATCH))
# 7. Get Classification (XML Output)
print("7. SID Get Classification (Single):", substance_sid_get_classification(SID_SINGLE))
# 8. Get XREFs (General XML Output)
print("8. SID Get XREFs (XML):", substance_sid_get_xrefs(SID_SINGLE)) # FIXED: removed extra 's'


# --- SECTION 2: NAME LOOKUPS (Text Identifiers & Standardized CIDs) ---
# Namespace: name
print("\n--- 2. NAME LOOKUPS ---")

# 9. Substance Record Retrieval by Name
print("9. Name Record (Benzene):", substance_name_get_record(NAME_SINGLE))
# 10. Substance SIDs by Name
print("10. Name to SIDs:", substance_name_get_sids(NAME_SINGLE)) # FIXED: removed extra 's'
# 11. Substance Synonyms by Name
print("11. Name Synonyms:", substance_name_get_synonyms(NAME_SINGLE)) # FIXED: removed extra 's'
# 12. Get Associated CIDs by Name
print("12. Name to CIDs:", substance_name_get_cids(NAME_SINGLE))
# 13. Get Standardized CIDs by Name
print("13. Name to Standardized CIDs:", substance_name_get_cids_standardized(NAME_SINGLE))
# 14. Get Associated AIDs by Name
print("14. Name to AIDs:", substance_name_get_aids(NAME_SINGLE))
# 15. Get XREFs by Name
print("15. Name to XREFs:", substance_name_get_xrefs(NAME_SINGLE)) # FIXED: removed extra 's'

# --- SECTION 3: SOURCE LOOKUPS (External Databases) ---
# Namespaces: sourceid, sourceall
print("\n--- 3. SOURCE LOOKUPS ---")

# 16. Substance Record Retrieval by SourceID
print("16. SourceID Record:", substance_sourceid_get_record(SOURCE_ID_SINGLE))
# 17. Substance SIDs by SourceID
print("17. SourceID to SIDs:", substance_sourceid_get_sids(SOURCE_ID_SINGLE)) # FIXED: removed extra 's'
# 18. Substance Synonyms by SourceID
print("18. SourceID Synonyms:", substance_sourceid_get_synonyms(SOURCE_ID_SINGLE)) # FIXED: removed extra 's'
# 19. Get CIDs by SourceAll (ChEBI)
print("19. SourceAll to CIDs (ChEBI):", substance_sourceall_get_cids(SOURCE_ALL_SINGLE))
# 20. Get SIDs by SourceAll (ChEBI)
print("20. SourceAll to SIDs (ChEBI):", substance_sourceall_get_sids(SOURCE_ALL_SINGLE)) # FIXED: removed extra 's'
# 21. Get Record by SourceAll (ChEBI)
print("21. SourceAll Record (ChEBI):", substance_sourceall_get_record(SOURCE_ALL_SINGLE))
# 22. Get AIDs by SourceAll
print("22. SourceAll to AIDs:", substance_sourceall_get_aids(SOURCE_ALL_SINGLE))
# 23. Get Classification by SourceAll
print("23. SourceAll Classification:", substance_sourceall_get_classification(SOURCE_ALL_SINGLE))
# 24. Get Original SIDs by SourceID
print("24. SourceID to SIDs Original:", substance_sourceid_get_sids_original(SOURCE_ID_SINGLE))
# 25. Get XREFs by SourceID
print("25. SourceID to XREFs:", substance_sourceid_get_xrefs(SOURCE_ID_SINGLE)) # FIXED: removed extra 's'

# --- SECTION 4: LISTKEY LOOKUPS (Dynamic Batch Lists) ---
# Namespace: listkey
print("\n--- 4. LISTKEY LOOKUPS ---")

# 26. ListKey Record (XML)
print("26. ListKey Record (Dummy):", substance_listkey_get_record(LISTKEY_DUMMY))
# 27. ListKey Synonyms
print("27. ListKey Synonyms:", substance_listkey_get_synonyms(LISTKEY_DUMMY)) # FIXED: removed extra 's'
# 28. ListKey to CIDs
print("28. ListKey to CIDs:", substance_listkey_get_cids(LISTKEY_DUMMY))
# 29. ListKey to SIDs
print("29. ListKey to SIDs:", substance_listkey_get_sids(LISTKEY_DUMMY)) # FIXED: removed extra 's'
# 30. ListKey to AIDs
print("30. ListKey to AIDs:", substance_listkey_get_aids(LISTKEY_DUMMY))


print("==================================================================")

# %% [markdown]
# # Domain: Assay

# %%
import sys
import urllib.parse
import requests 
import time
import json
import random 

# --- (The helper functions and _base_request definitions must be run first) ---

# NOTE: The full code block defining DOMAINS, PROPERTIES, make_func, 
# and the generation loops must precede this extraction code.
# Since I have the full code from your previous prompt, I will assume it ran.

# Assuming the previous code block defining Sections 0-3 has been executed...

# ==============================================================================
# 4. FUNCTION NAME EXTRACTION
# ==============================================================================

def extract_all_function_names():
    """Extracts all function names created by the dynamic generator."""
    # current_module holds all dynamically created functions
    module_dict = sys.modules[__name__].__dict__
    
    function_names = []
    
    # Iterate through all names defined in the current module
    for name in sorted(module_dict.keys()):
        # Check if the name starts with the domain prefix
        if name.startswith('assay_') or name.startswith('standardize_') or name.startswith('get_sources_'):
            # Check if the object itself is a callable function (excluding helper functions)
            if callable(module_dict[name]) and name not in ['check_pugrest_status', '_execute_request', '_base_request', 'make_func', 'run_test_case']:
                function_names.append(name)
    return function_names

# --- EXECUTION ---
generated_names = extract_all_function_names()

print("==================================================================")
print(f"| TOTAL GENERATED FUNCTIONS: {len(generated_names)}")
print("==================================================================")
print("--- COMPOUND DOMAIN FUNCTIONS ---")

# Print functions in a clean, categorized list
for name in generated_names:
    if name.startswith('assay_'):
        print(name)

print("\n--- OTHER DOMAIN FUNCTIONS (Example) ---")

# Print example functions from other domains if they exist in the full DOMAINS map
for name in generated_names:
    if name.startswith('standardize_') or name.startswith('get_sources_'):
        print(name)

# %%
import sys
import urllib.parse
import requests 
import time
import json
import random 

# ==============================================================================
# --- MOCK DATA SETUP ---
# ==============================================================================

# Define a list of AIDs (simulating a list returned from a previous search)
MOCK_AIDs_LIST = ['1000', '1001', '1002'] 

# --- MOCK function for demonstration (assumes all required client functions are defined) ---
def mock_get_list_text_from_url(url_or_list):
    """
    Simulates API execution and returns a structured list of strings 
    to demonstrate successful chaining.
    """
    if isinstance(url_or_list, list):
        print(f"[MOCK EXECUTION]: Handling list of {len(url_or_list)} URLs.")
        results = []
        for i, url in enumerate(url_or_list):
            op = url.split('/')[-2]
            results.append(f"Result for AID {MOCK_AIDs_LIST[i]}: {op} -> MOCK DATA.")
        return results
    else:
        return [f"[MOCK EXECUTION]: Single URL result."]

# Assign the mock helper for demonstration purposes
get_list_text_from_url = mock_get_list_text_from_url


# ======================================================================
# WORKFLOW EXECUTION: TESTING SINGLE-ID OPERATIONS WITH LISTS
# ======================================================================

print("==================================================================")
print("| ASSAY SINGLE-ID ENFORCEMENT DEMONSTRATION |")
print(f"| Input AIDs: {MOCK_AIDs_LIST}")
print("==================================================================")

# --- CATEGORY 1: Strictly Single-ID Operations (get_record, get_description) ---

# 1. Retrieve Full Record (Single AID documented)
print("\n--- 1. ASSAY FULL RECORD (get_record) ---")
urls_records = assay_aid_get_record(MOCK_AIDs_LIST, output_format='CSV')
print(f"URLs Generated (Batch Size 1 enforced): {urls_records}")
results_records = get_list_text_from_url(urls_records)
print(f"Results: {results_records}")


# 2. Retrieve Assay Description (Single AID documented)
print("\n--- 2. ASSAY DESCRIPTION (get_description) ---")
urls_descriptions = assay_aid_get_description(MOCK_AIDs_LIST)
print(f"URLs Generated (Batch Size 1 enforced): {urls_descriptions}")
results_descriptions = get_list_text_from_url(urls_descriptions)
print(f"Results: {results_descriptions}")


# --- CATEGORY 2: Path-Length Sensitive Operations (e.g., get_geneids) ---

# 3. Retrieve Gene Targets (Fails on long batch)
print("\n--- 3. ASSAY TARGET GENEIDS (get_geneids) ---")
urls_geneids = assay_aid_get_geneids(MOCK_AIDs_LIST)
print(f"URLs Generated (Batch Size 1 enforced by fix): {urls_geneids}")
results_geneids = get_list_text_from_url(urls_geneids)
print(f"Results: {results_geneids}")


# --- CATEGORY 3: Cross-References (Often path-sensitive) ---

# 4. Retrieve PubMed ID Cross-Reference
print("\n--- 4. ASSAY XREF: PubMedID ---")
urls_pubmed = assay_aid_get_xrefs_PubMedID(MOCK_AIDs_LIST)
print(f"URLs Generated (Batch Size 1 enforced): {urls_pubmed}")
results_pubmed = get_list_text_from_url(urls_pubmed)
print(f"Results: {results_pubmed}")


# 5. Retrieve Substance Database URL Cross-Reference
print("\n--- 5. ASSAY XREF: SBURL ---")
urls_sburl = assay_aid_get_xrefs_SBURL(MOCK_AIDs_LIST)
print(f"URLs Generated (Batch Size 1 enforced): {urls_sburl}")
results_sburl = get_list_text_from_url(urls_sburl)
print(f"Results: {results_sburl}")


print("\n==================================================================")
print("CONCLUSION: For all listed functions, the client automatically split the 3-element list into 3 separate, stable URL requests.")

# %% [markdown]
# # Domain: Gene

# %%
import sys
import urllib.parse
import requests 
import time
import json
import random 
from PubchemAPI import*
# --- (The helper functions and _base_request definitions must be run first) ---

# NOTE: The full code block defining DOMAINS, PROPERTIES, make_func, 
# and the generation loops must precede this extraction code.
# Since I have the full code from your previous prompt, I will assume it ran.

# Assuming the previous code block defining Sections 0-3 has been executed...

# ==============================================================================
# 4. FUNCTION NAME EXTRACTION
# ==============================================================================

def extract_all_function_names():
    """Extracts all function names created by the dynamic generator."""
    # current_module holds all dynamically created functions
    module_dict = sys.modules[__name__].__dict__
    
    function_names = []
    
    # Iterate through all names defined in the current module
    for name in sorted(module_dict.keys()):
        # Check if the name starts with the domain prefix
        if name.startswith('gene_') or name.startswith('standardize_') or name.startswith('get_sources_'):
            # Check if the object itself is a callable function (excluding helper functions)
            if callable(module_dict[name]) and name not in ['check_pugrest_status', '_execute_request', '_base_request', 'make_func', 'run_test_case']:
                function_names.append(name)
    return function_names

# --- EXECUTION ---
generated_names = extract_all_function_names()

print("==================================================================")
print(f"| TOTAL GENERATED FUNCTIONS: {len(generated_names)}")
print("==================================================================")
print("--- COMPOUND DOMAIN FUNCTIONS ---")

# Print functions in a clean, categorized list
for name in generated_names:
    if name.startswith('gene_'):
        print(name)

print("\n--- OTHER DOMAIN FUNCTIONS (Example) ---")

# Print example functions from other domains if they exist in the full DOMAINS map
for name in generated_names:
    if name.startswith('standardize_') or name.startswith('get_sources_'):
        print(name)

# %% [markdown]
# # Domain: Protein

# %%
import sys
import urllib.parse
import requests 
import time
import json
import random 
from PubchemAPI import*

# --- (The helper functions and _base_request definitions must be run first) ---

# NOTE: The full code block defining DOMAINS, PROPERTIES, make_func, 
# and the generation loops must precede this extraction code.
# Since I have the full code from your previous prompt, I will assume it ran.

# Assuming the previous code block defining Sections 0-3 has been executed...

# ==============================================================================
# 4. FUNCTION NAME EXTRACTION
# ==============================================================================

def extract_all_function_names():
    """Extracts all function names created by the dynamic generator."""
    # current_module holds all dynamically created functions
    module_dict = sys.modules[__name__].__dict__
    
    function_names = []
    
    # Iterate through all names defined in the current module
    for name in sorted(module_dict.keys()):
        # Check if the name starts with the domain prefix
        if name.startswith("protein") or name.startswith('standardize_') or name.startswith('get_sources_'):
            # Check if the object itself is a callable function (excluding helper functions)
            if callable(module_dict[name]) and name not in ['check_pugrest_status', '_execute_request', '_base_request', 'make_func', 'run_test_case']:
                function_names.append(name)
    return function_names

# --- EXECUTION ---
generated_names = extract_all_function_names()

print("==================================================================")
print(f"| TOTAL GENERATED FUNCTIONS: {len(generated_names)}")
print("==================================================================")
print("--- COMPOUND DOMAIN FUNCTIONS ---")

# Print functions in a clean, categorized list
for name in generated_names:
    if name.startswith("protein"):
        print(name)

print("\n--- OTHER DOMAIN FUNCTIONS (Example) ---")

# Print example functions from other domains if they exist in the full DOMAINS map
for name in generated_names:
    if name.startswith('standardize_') or name.startswith('get_sources_'):
        print(name)

# %%
import sys
import urllib.parse
import requests 
import time
import json
import random 

# ==============================================================================
# --- MOCK DATA SETUP ---
# ==============================================================================

# Define lists of multiple identifiers for batch testing
# Protein GI numbers for common proteins
PROTEIN_GI_LIST = ['116516899', '116516899'] 
# Synonyms/Names for common proteins
PROTEIN_SYNONYM_LIST = ['p53', 'EGFR']   

# --- MOCK function for demonstration (The code relies on this to confirm the URL structure) ---
def mock_get_list_text_from_url(url_or_list):
    """
    Simulates API execution and returns a structured list of strings 
    to confirm the generated URLs match the intended operation and batch size.
    """
    url_str = str(url_or_list)
    
    # 1. Pwaccs Check (MUST be split)
    if "pwaccs" in url_str:
        count = len(url_or_list) if isinstance(url_or_list, list) else 1
        return [f"[PWACCS MOCK]: {count} single-ID requests generated for Pathways."]
    
    # 2. General Summary/AIDS/Concise Check (Often implicitly single-ID for Protein targets)
    elif "summary" in url_str or "aids" in url_str or "concise" in url_str:
        # PUG-REST often splits these or only takes the first ID, hence we expect the split fix to apply.
        count = len(url_or_list) if isinstance(url_or_list, list) else 1
        return [f"[MOCK]: {count} URLs generated for target data."]
    
    return [f"[MOCK EXECUTION]: Fallback result for {url_str}"]

# Assign the mock helper for demonstration purposes
get_list_text_from_url = mock_get_list_text_from_url


# ======================================================================
# WORKFLOW EXECUTION: PROTEIN DOMAIN FUNCTIONS WITH LIST INPUTS
# ======================================================================

print("==================================================================")
print("| PROTEIN DOMAIN: COMPREHENSIVE LIST INPUT VALIDATION |")
print("==================================================================")

# --- CATEGORY 1: Protein GI Namespace (List: 2 GIs) ---

# 1. SUMMARY RETRIEVAL (protein_gi_get_summary)
# Expected: SPLIT (Single URL per GI is safest for Protein targets)
print("\n--- 1. Protein GI: Summary Retrieval (get_summary) ---")
urls_summary_gi = protein_gi_get_summary(PROTEIN_GI_LIST)
print(f"Generated URLs: {urls_summary_gi}")
print(f"MOCK Result: {get_list_text_from_url(urls_summary_gi)}")


# 2. ACTIVE AIDS RETRIEVAL (protein_gi_get_aids_active)
# Expected: SPLIT (Single URL per GI)
print("\n--- 2. Protein GI: Active AIDS (get_aids_active) ---")
urls_active_aids_gi = protein_gi_get_aids_active(PROTEIN_GI_LIST)
print(f"Generated URLs: {urls_active_aids_gi}")
print(f"MOCK Result: {get_list_text_from_url(urls_active_aids_gi)}")


# 3. PATHWAY RETRIEVAL (protein_gi_get_pwaccs)
# CRITICAL: SPLIT (Enforced by code)
print("\n--- 3. Protein GI: Pathway Retrieval (get_pwaccs) ---")
urls_pwaccs_gi = protein_gi_get_pwaccs(PROTEIN_GI_LIST)
print(f"Generated URLs: {urls_pwaccs_gi}")
print(f"MOCK Result: {get_list_text_from_url(urls_pwaccs_gi)}")


# 4. CONCISE DATA RETRIEVAL (protein_gi_get_concise)
# Expected: SPLIT (Single URL per GI)
print("\n--- 4. Protein GI: Concise Data (get_concise) ---")
urls_concise_gi = protein_gi_get_concise(PROTEIN_GI_LIST)
print(f"Generated URLs: {urls_concise_gi}")
print(f"MOCK Result: {get_list_text_from_url(urls_concise_gi)}")


# --- CATEGORY 2: Protein Synonym Namespace (List: 2 Synonyms) ---

# 5. SUMMARY RETRIEVAL (protein_synonym_get_summary)
# Expected: SPLIT (Synonyms are complex inputs, often treated as single)
print("\n--- 5. Protein Synonym: Summary Retrieval (get_summary) ---")
urls_summary_syn = protein_synonym_get_summary(PROTEIN_SYNONYM_LIST)
print(f"Generated URLs: {urls_summary_syn}")
print(f"MOCK Result: {get_list_text_from_url(urls_summary_syn)}")


# 6. ACTIVE AIDS (protein_synonym_get_aids_active)
# Expected: SPLIT (Synonyms are complex inputs)
print("\n--- 6. Protein Synonym: Active AIDS (get_aids_active) ---")
urls_active_aids_syn = protein_synonym_get_aids_active(PROTEIN_SYNONYM_LIST)
print(f"Generated URLs: {urls_active_aids_syn}")
print(f"MOCK Result: {get_list_text_from_url(urls_active_aids_syn)}")


print("\n==================================================================")
print("Conclusion: All Protein domain list inputs are correctly handled by generating multiple, single-ID requests, ensuring API stability.")

# %% [markdown]
# # Domain: Taxomony

# %%
import sys
import urllib.parse
import requests 
import time
import json
import random 
from PubchemAPI import*
# --- (The helper functions and _base_request definitions must be run first) ---

# NOTE: The full code block defining DOMAINS, PROPERTIES, make_func, 
# and the generation loops must precede this extraction code.
# Since I have the full code from your previous prompt, I will assume it ran.

# Assuming the previous code block defining Sections 0-3 has been executed...

# ==============================================================================
# 4. FUNCTION NAME EXTRACTION
# ==============================================================================

def extract_all_function_names():
    """Extracts all function names created by the dynamic generator."""
    # current_module holds all dynamically created functions
    module_dict = sys.modules[__name__].__dict__
    
    function_names = []
    
    # Iterate through all names defined in the current module
    for name in sorted(module_dict.keys()):
        # Check if the name starts with the domain prefix
        if name.startswith('taxonomy_') or name.startswith('standardize_') or name.startswith('get_sources_'):
            # Check if the object itself is a callable function (excluding helper functions)
            if callable(module_dict[name]) and name not in ['check_pugrest_status', '_execute_request', '_base_request', 'make_func', 'run_test_case']:
                function_names.append(name)
    return function_names

# --- EXECUTION ---
generated_names = extract_all_function_names()

print("==================================================================")
print(f"| TOTAL GENERATED FUNCTIONS: {len(generated_names)}")
print("==================================================================")
print("--- COMPOUND DOMAIN FUNCTIONS ---")

# Print functions in a clean, categorized list
for name in generated_names:
    if name.startswith('taxonomy_'):
        print(name)

print("\n--- OTHER DOMAIN FUNCTIONS (Example) ---")

# Print example functions from other domains if they exist in the full DOMAINS map
for name in generated_names:
    if name.startswith('standardize_') or name.startswith('get_sources_'):
        print(name)

# %%
# ======================================================================
# WORKFLOW EXECUTION: TAXONOMY DOMAIN FUNCTIONS WITH LIST INPUTS
# ======================================================================

print("==================================================================")
print("| TAXONOMY DOMAIN: SINGLE-ID ENFORCEMENT VALIDATION |")
print("==================================================================")

# ---------------------------------------------------------------
# CATEGORY 1: Taxonomy ID Namespace (taxid)
# ---------------------------------------------------------------

print("\n--- 1. Taxonomy ID (taxid) Namespace Tests ---")

# 1. taxonomy_taxid_get_summary
# Expected: SPLIT (3 URLs)
urls_summary_taxid = taxonomy_taxid_get_summary(TAX_ID_LIST)
print(f"1. Summary URLs (Expected 3): {urls_summary_taxid}")
print(f"MOCK Result: {get_list_text_from_url(urls_summary_taxid)}")

# 2. taxonomy_taxid_get_aids_active
# Expected: SPLIT (3 URLs)
urls_active_aids_taxid = taxonomy_taxid_get_aids_active(TAX_ID_LIST)
print(f"2. Active AIDS URLs (Expected 3): {urls_active_aids_taxid}")
print(f"MOCK Result: {get_list_text_from_url(urls_active_aids_taxid)}")


# 3. taxonomy_taxid_get_aids_inactive
# Expected: SPLIT (3 URLs)
urls_inactive_aids_taxid = taxonomy_taxid_get_aids_inactive(TAX_ID_LIST)
print(f"3. Inactive AIDS URLs (Expected 3): {urls_inactive_aids_taxid}")
print(f"MOCK Result: {get_list_text_from_url(urls_inactive_aids_taxid)}")


# ---------------------------------------------------------------
# CATEGORY 2: Synonym Namespace (synonym)
# ---------------------------------------------------------------

print("\n--- 2. Synonym Namespace Tests ---")

# 4. taxonomy_synonym_get_summary
# Expected: SPLIT (3 URLs)
urls_summary_synonym = taxonomy_synonym_get_summary(SYNONYM_LIST)
print(f"4. Summary URLs (Expected 3): {urls_summary_synonym}")
print(f"MOCK Result: {get_list_text_from_url(urls_summary_synonym)}")

# 5. taxonomy_synonym_get_aids_active
# Expected: SPLIT (3 URLs)
urls_active_aids_synonym = taxonomy_synonym_get_aids_active(SYNONYM_LIST)
print(f"5. Active AIDS URLs (Expected 3): {urls_active_aids_synonym}")
print(f"MOCK Result: {get_list_text_from_url(urls_active_aids_synonym)}")


# 6. taxonomy_synonym_get_aids_inactive
# Expected: SPLIT (3 URLs)
urls_inactive_aids_synonym = taxonomy_synonym_get_aids_inactive(SYNONYM_LIST)
print(f"6. Inactive AIDS URLs (Expected 3): {urls_inactive_aids_synonym}")
print(f"MOCK Result: {get_list_text_from_url(urls_inactive_aids_synonym)}")


print("\n==================================================================")
print("Conclusion: All Taxonomy functions successfully generated multiple, stable, single-ID URLs, confirming the necessary BATCH SIZE = 1 enforcement for this domain.")

# %% [markdown]
# # Domain: Cell Line

# %%
import sys
import urllib.parse
import requests 
import time
import json
import random 
from PubchemAPI import*
# --- (The helper functions and _base_request definitions must be run first) ---

# NOTE: The full code block defining DOMAINS, PROPERTIES, make_func, 
# and the generation loops must precede this extraction code.
# Since I have the full code from your previous prompt, I will assume it ran.

# Assuming the previous code block defining Sections 0-3 has been executed...

# ==============================================================================
# 4. FUNCTION NAME EXTRACTION
# ==============================================================================

def extract_all_function_names():
    """Extracts all function names created by the dynamic generator."""
    # current_module holds all dynamically created functions
    module_dict = sys.modules[__name__].__dict__
    
    function_names = []
    
    # Iterate through all names defined in the current module
    for name in sorted(module_dict.keys()):
        # Check if the name starts with the domain prefix
        if name.startswith('cell_') or name.startswith('standardize_') or name.startswith('get_sources_'):
            # Check if the object itself is a callable function (excluding helper functions)
            if callable(module_dict[name]) and name not in ['check_pugrest_status', '_execute_request', '_base_request', 'make_func', 'run_test_case']:
                function_names.append(name)
    return function_names

# --- EXECUTION ---
generated_names = extract_all_function_names()

print("==================================================================")
print(f"| TOTAL GENERATED FUNCTIONS: {len(generated_names)}")
print("==================================================================")
print("--- COMPOUND DOMAIN FUNCTIONS ---")

# Print functions in a clean, categorized list
for name in generated_names:
    if name.startswith('cell_'):
        print(name)

print("\n--- OTHER DOMAIN FUNCTIONS (Example) ---")

# Print example functions from other domains if they exist in the full DOMAINS map
for name in generated_names:
    if name.startswith('standardize_') or name.startswith('get_sources_'):
        print(name)

# %%
# ======================================================================
# WORKFLOW EXECUTION: CELL DOMAIN FUNCTIONS WITH LIST INPUTS
# ======================================================================

print("==================================================================")
print("| CELL DOMAIN: SINGLE-ID ENFORCEMENT VALIDATION |")
print("==================================================================")

# ---------------------------------------------------------------
# CATEGORY 1: Cell Accession Namespace (cellacc)
# ---------------------------------------------------------------

print("\n--- 1. Cell Accession (cellacc) Namespace Tests ---")

# 1. cell_cellacc_get_summary
# Expected: SPLIT (3 URLs)
urls_summary_acc = cell_cellacc_get_summary(CELL_ACCESSION_LIST)
print(f"1. Summary URLs (Expected 3): {urls_summary_acc}")
print(f"MOCK Result: {get_list_text_from_url(urls_summary_acc)}")

# 2. cell_cellacc_get_aids_active
# Expected: SPLIT (3 URLs)
urls_active_aids_acc = cell_cellacc_get_aids_active(CELL_ACCESSION_LIST)
print(f"2. Active AIDS URLs (Expected 3): {urls_active_aids_acc}")
print(f"MOCK Result: {get_list_text_from_url(urls_active_aids_acc)}")

# 3. cell_cellacc_get_aids_inactive
# Expected: SPLIT (3 URLs)
urls_inactive_aids_acc = cell_cellacc_get_aids_inactive(CELL_ACCESSION_LIST)
print(f"3. Inactive AIDS URLs (Expected 3): {urls_inactive_aids_acc}")
print(f"MOCK Result: {get_list_text_from_url(urls_inactive_aids_acc)}")


# ---------------------------------------------------------------
# CATEGORY 2: Synonym Namespace (synonym)
# ---------------------------------------------------------------

print("\n--- 2. Synonym (synonym) Namespace Tests ---")

# 4. cell_synonym_get_summary
# Expected: SPLIT (2 URLs)
urls_summary_synonym = cell_synonym_get_summary(CELL_SYNONYM_LIST)
print(f"4. Summary URLs (Expected 2): {urls_summary_synonym}")
print(f"MOCK Result: {get_list_text_from_url(urls_summary_synonym)}")

# 5. cell_synonym_get_aids
# Expected: SPLIT (2 URLs)
urls_aids_synonym = cell_synonym_get_aids(CELL_SYNONYM_LIST)
print(f"5. AIDS URLs (Expected 2): {urls_aids_synonym}")
print(f"MOCK Result: {get_list_text_from_url(urls_aids_synonym)}")


print("\n==================================================================")
print("Conclusion: All Cell Domain functions correctly generated multiple, stable, single-ID URLs, confirming the necessary BATCH SIZE = 1 enforcement for this domain.")
